# %% [markdown]
# # Lab | Data Structuring and Combining Data

# %% [markdown]
# ## Challenge 1: Combining & Cleaning Data
#
# In this challenge, we will be working with the customer data from an insurance company, as we did in the two previous labs. The data can be found here:
# - https://raw.githubusercontent.com/data-bootcamp-v4/data/main/file1.csv
#
# But this time, we got new data, which can be found in the following 2 CSV files located at the links below.
#
# - https://raw.githubusercontent.com/data-bootcamp-v4/data/main/file2.csv
# - https://raw.githubusercontent.com/data-bootcamp-v4/data/main/file3.csv
#
# Note that you'll need to clean and format the new data.
#
# Observation:
# - One option is to first combine the three datasets and then apply the cleaning function to the new combined dataset
# - Another option would be to read the clean file you saved in the previous lab, and just clean the two new files and concatenate the three clean datasets

# %%
import pandas as pd
from data_cleaning import (
    standardize_column_names,
    clean_inconsistent_values,
    correct_data_types,
    handle_nulls_and_convert_numeric,
    remove_duplicates
)

def load_and_clean_new_data():
    # Step 1: Load already cleaned file1
    file1_clean = pd.read_csv("cleaned_data.csv")  # from previous lab

    # Step 2: Load file2 and file3 from URLs
    url2 = "https://raw.githubusercontent.com/data-bootcamp-v4/data/main/file2.csv"
    url3 = "https://raw.githubusercontent.com/data-bootcamp-v4/data/main/file3.csv"

    file2 = pd.read_csv(url2)
    file3 = pd.read_csv(url3)

    # Step 3: Clean new files
    def clean(df):
        df = standardize_column_names(df)
        df = clean_inconsistent_values(df)
        df = correct_data_types(df)
        df = handle_nulls_and_convert_numeric(df)
        df = remove_duplicates(df)
        return df

    file2_clean = clean(file2)
    file3_clean = clean(file3)

    # Step 4: Combine all three
    combined_df = pd.concat([file1_clean, file2_clean, file3_clean], ignore_index=True)

    # Step 5: Final deduplication and export
    combined_df = remove_duplicates(combined_df)
    combined_df.to_csv("final_cleaned_combined_data.csv", index=False)

    print("✅ All files cleaned and combined. Saved as 'final_cleaned_combined_data.csv'")
    return combined_df
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[41], line 2
#       1 import pandas as pd
# ----> 2 from data_cleaning import (
#       3     standardize_column_names,
#       4     clean_inconsistent_values,
#       5     correct_data_types,
#       6     handle_nulls_and_convert_numeric,
#       7     remove_duplicates
#       8 )
#      10 def load_and_clean_new_data():
#      11     # Step 1: Load already cleaned file1
#      12     file1_clean = pd.read_csv("cleaned_data.csv")  # from previous lab
#
# ModuleNotFoundError: No module named 'data_cleaning'

# %% [markdown]
# # Challenge 2: Structuring Data

# %% [markdown]
# In this challenge, we will continue to work with customer data from an insurance company, but we will use a dataset with more columns, called marketing_customer_analysis.csv, which can be found at the following link:
#
# https://raw.githubusercontent.com/data-bootcamp-v4/data/main/marketing_customer_analysis_clean.csv
#
# This dataset contains information such as customer demographics, policy details, vehicle information, and the customer's response to the last marketing campaign. Our goal is to explore and analyze this data by performing data cleaning, formatting, and structuring.

# %%
import pandas as pd 

df= pd.read_csv('https://raw.githubusercontent.com/data-bootcamp-v4/data/main/marketing_customer_analysis_clean.csv')

df
# Out:
#        unnamed:_0 customer       state  customer_lifetime_value response  \
# 0               0  DK49336     Arizona              4809.216960       No
# 1               1  KX64629  California              2228.525238       No
# 2               2  LZ68649  Washington             14947.917300       No
# 3               3  XL78013      Oregon             22332.439460      Yes
# 4               4  QA50777      Oregon              9025.067525       No
# ...           ...      ...         ...                      ...      ...
# 10905       10905  FE99816      Nevada             15563.369440       No
# 10906       10906  KX53892      Oregon              5259.444853       No
# 10907       10907  TL39050     Arizona             23893.304100       No
# 10908       10908  WA60547  California             11971.977650       No
# 10909       10909  IV32877  California              6857.519928       No
#
#        coverage education effective_to_date employmentstatus gender  ...  \
# ...

# %% [markdown]
# 1. You work at the marketing department and you want to know which sales channel brought the most sales in terms of total revenue. Using pivot, create a summary table showing the total revenue for each sales channel (branch, call center, web, and mail).
# Round the total revenue to 2 decimal points.  Analyze the resulting table to draw insights.

# %% [markdown]
# 2. Create a pivot table that shows the average customer lifetime value per gender and education level. Analyze the resulting table to draw insights.

# %%
def total_revenue_by_sales_channel(df):
    revenue_pivot = pd.pivot_table(
        df,
        values='total_claim_amount',
        index='sales_channel',
        aggfunc='sum'
    ).round(2).sort_values(by='total_claim_amount', ascending=False)

    print("Total Revenue by Sales Channel:\n")
    print(revenue_pivot)
    return revenue_pivot

# %%
def avg_clv_by_gender_education(df):
    clv_pivot = pd.pivot_table(
        df,
        values='customer_lifetime_value',
        index='gender',
        columns='education',
        aggfunc='mean'
    ).round(2)

    print("\nAverage Customer Lifetime Value by Gender and Education:\n")
    print(clv_pivot)
    return clv_pivot

# %%
# Run analysis functions
revenue_summary = total_revenue_by_sales_channel(df)

clv_summary = avg_clv_by_gender_education(df)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[65], line 2
#       1 # Run analysis functions
# ----> 2 revenue_summary = total_revenue_by_sales_channel(df)
#       4 clv_summary = avg_clv_by_gender_education(df)
#
# Cell In[61], line 2, in total_revenue_by_sales_channel(df)
#       1 def total_revenue_by_sales_channel(df):
# ----> 2     revenue_pivot = pd.pivot_table(
#       3         df,
#       4         values='total_claim_amount',
#       5         index='sales_channel',
#       6         aggfunc='sum'
#       7     ).round(2).sort_values(by='total_claim_amount', ascending=False)
#       9     print("Total Revenue by Sales Channel:\n")
#      10     print(revenue_pivot)
#
# ...

# %% [markdown]
# ## Bonus
#
# You work at the customer service department and you want to know which months had the highest number of complaints by policy type category. Create a summary table showing the number of complaints by policy type and month.
# Show it in a long format table.

# %% [markdown]
# *In data analysis, a long format table is a way of structuring data in which each observation or measurement is stored in a separate row of the table. The key characteristic of a long format table is that each column represents a single variable, and each row represents a single observation of that variable.*
#
# *More information about long and wide format tables here: https://www.statology.org/long-vs-wide-data/*

# %%
def complaints_by_policy_and_month(df):
    # Filter rows with actual complaints (greater than 0)
    complaints_df = df[df['number_of_open_complaints'] > 0]

    # Group by policy_type and month, count number of complaints
    summary = complaints_df.groupby(['policy_type', 'month']).size().reset_index(name='number_of_complaints')

    # Sort by most complaints
    summary = summary.sort_values(by='number_of_complaints', ascending=False)

    print("📋 Complaints by Policy Type and Month:\n")
    print(summary)
    return summary

def clean_open_complaints_column(df):
    # Convert to string and extract the middle value if it's in "x/y/z" format
    df['number_of_open_complaints'] = df['number_of_open_complaints'].astype(str).apply(
        lambda x: x.split('/')[1] if '/' in x and len(x.split('/')) >= 2 else x
    )

    # Convert to numeric type
    df['number_of_open_complaints'] = pd.to_numeric(df['number_of_open_complaints'], errors='coerce')

    return df

# %%
url = "https://raw.githubusercontent.com/data-bootcamp-v4/data/main/file2.csv"
df = pd.read_csv(url)

# Make sure number_of_open_complaints is numeric
df['number_of_open_complaints'] = pd.to_numeric(df['number_of_open_complaints'], errors='coerce')

# Call the function
complaint_summary = complaints_by_policy_and_month(df)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File /opt/anaconda3/lib/python3.12/site-packages/pandas/core/indexes/base.py:3805, in Index.get_loc(self, key)
#    3804 try:
# -> 3805     return self._engine.get_loc(casted_key)
#    3806 except KeyError as err:
#
# File index.pyx:167, in pandas._libs.index.IndexEngine.get_loc()
#
# File index.pyx:196, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas/_libs/hashtable_class_helper.pxi:7081, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas/_libs/hashtable_class_helper.pxi:7089, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'number_of_open_complaints'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[75], line 5
#       2 df = pd.read_csv(url)
# ...
